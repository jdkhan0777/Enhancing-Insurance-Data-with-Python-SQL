# %% [markdown]
# 1.**Importing the CSV File**

# %% [markdown]
# # New Section

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-87f37c4a-d1ec-46d7-aff5-51ad591eee55" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87f37c4a-d1ec-46d7-aff5-51ad591eee55">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df= pd.read_csv("VehicleInsuranceData.csv")
df.head()
# Out:
#    Unnamed: 0           clv Response  Coverage Education EmploymentStatus  \
# 0           1   2763.519279       No     Basic  Bachelor         Employed
# 1           2   6979.535903       No  Extended  Bachelor       Unemployed
# 2           3  12887.431650       No   Premium  Bachelor         Employed
# 3           4   7645.861827       No     Basic  Bachelor       Unemployed
# 4           5   2813.692575       No     Basic  Bachelor         Employed
#
#   Gender  Income Location.Code Marital.Status  ...  \
# 0      F   56274      Suburban        Married  ...
# 1      F       0      Suburban         Single  ...
# 2      F   48767      Suburban        Married  ...
# 3      M       0      Suburban        Married  ...
# 4      M   43836         Rural         Single  ...
#
#    Months.Since.Policy.Inception  Number.of.Open.Complaints  \
# 0                              5                          0
# 1                             42                          0
# ...

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'VehicleInsuranceData (1).csv',
#  'VehicleInsuranceData.csv',
#  'sample_data']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8630 entries, 0 to 8629
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     8630 non-null   int64
#  1   clv                            8630 non-null   float64
#  2   Response                       8630 non-null   object
#  3   Coverage                       8630 non-null   object
#  4   Education                      8630 non-null   object
#  5   EmploymentStatus               8630 non-null   object
#  6   Gender                         8630 non-null   object
#  7   Income                         8630 non-null   int64
#  8   Location.Code                  8630 non-null   object
#  9   Marital.Status                 8630 non-null   object
#  10  Monthly.Premium.Auto           8630 non-null   int64
#  11  Months.Since.Last.Claim        8630 non-null   int64
# ...

# %% [markdown]
# 2.**Removing the unnamed coulmn**

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)
df.head()
# Out:
#             clv Response  Coverage Education EmploymentStatus Gender  Income  \
# 0   2763.519279       No     Basic  Bachelor         Employed      F   56274
# 1   6979.535903       No  Extended  Bachelor       Unemployed      F       0
# 2  12887.431650       No   Premium  Bachelor         Employed      F   48767
# 3   7645.861827       No     Basic  Bachelor       Unemployed      M       0
# 4   2813.692575       No     Basic  Bachelor         Employed      M   43836
#
#   Location.Code Marital.Status  Monthly.Premium.Auto  ...  \
# 0      Suburban        Married                    69  ...
# 1      Suburban         Single                    94  ...
# 2      Suburban        Married                   108  ...
# 3      Suburban        Married                   106  ...
# 4         Rural         Single                    73  ...
#
#    Months.Since.Policy.Inception  Number.of.Open.Complaints  \
# 0                              5                          0
# ...

# %% [markdown]
# 3.**Checking for missing values**

# %%
df.isnull().sum()
# Out:
# clv                              0
# Response                         0
# Coverage                         0
# Education                        0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location.Code                    0
# Marital.Status                   0
# Monthly.Premium.Auto             0
# Months.Since.Last.Claim          0
# Months.Since.Policy.Inception    0
# Number.of.Open.Complaints        0
# Number.of.Policies               0
# Policy.Type                      0
# Policy                           0
# Renew.Offer.Type                 0
# Sales.Channel                    0
# Total.Claim.Amount               0
# Vehicle.Class                    0
# Vehicle.Size                     0
# dtype: int64

# %% [markdown]
# 4.**Checking duplicates values**

# %%
df.duplicated().sum()
# Out:
# 482

# %%
df[df.duplicated()].head(10)
# Out:
#                clv Response  Coverage             Education EmploymentStatus  \
# 242    4772.943848      Yes  Extended  High School or Below          Retired
# 365    3873.647046      Yes     Basic               College          Retired
# 500    6846.150323      Yes  Extended              Bachelor       Unemployed
# 559    3731.504584      Yes  Extended  High School or Below       Unemployed
# 658   12157.329920      Yes   Premium  High School or Below         Employed
# 908   10656.881950      Yes  Extended              Bachelor         Employed
# 912    4458.113369      Yes     Basic              Bachelor          Retired
# 972    4458.113369      Yes     Basic              Bachelor          Retired
# 992    2248.449633      Yes     Basic              Bachelor          Retired
# 1029   3436.134281      Yes  Extended                Doctor         Employed
#
#      Gender  Income Location.Code Marital.Status  Monthly.Premium.Auto  ...  \
# ...

# %% [markdown]
# 5.Removing duplicates

# %%
df.drop_duplicates(inplace= True)

# %% [markdown]
# 6.All the duplicates values remove from the data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 6.Detecting outliers

# %%
# Select only numerical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Create a boxplot for each numerical column
plt.figure(figsize=(12,6))
df[numerical_cols].boxplot(rot=45)  # Rotate labels for better readability
plt.title("Boxplot for Detecting Outliers")
plt.show()

# %% [markdown]
# # Sowing numbers of outliers in each coulmn

# %%
from scipy import stats
import numpy as np

# Compute Z-scores for numerical columns
z_scores = np.abs(stats.zscore(df[numerical_cols]))

# Find rows where any column has a Z-score > 3
outliers = (z_scores > 3).sum()

# Print the number of outliers per column
print("Number of outliers in each column:")
print(outliers)
# Out:
# Number of outliers in each column:
# clv                              149
# Income                             0
# Monthly.Premium.Auto             212
# Months.Since.Last.Claim            0
# Months.Since.Policy.Inception      0
# Number.of.Open.Complaints        189
# Number.of.Policies                 0
# Total.Claim.Amount               142
# dtype: int64

# %% [markdown]
# # **Transform outliers to reduce the effect on data**

# %%
import numpy as np
df["Income"] = np.log1p(df["Income"])  # Log transformation

# %% [markdown]
# # **Visualizing Distributions**

# %%
df["Total.Claim.Amount"].hist(bins=30)
plt.xlabel("Total Claim Amount")
plt.ylabel("Frequency")
plt.title("Distribution of Claim Amounts")
plt.show()

# %% [markdown]
# Converting data into CSV

# %%
df.to_csv("cleaned_insurance_data.csv", index=False)

# %%
from google.colab import files
files.download("cleaned_insurance_data.csv")
